# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics

# Data import and split
data = pd.read_csv("Naive-Bayes-Classification-Data.csv")
print(data)
X = data.drop('diabetes', axis=1)
y = data['diabetes']
# print(X)
# print(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)
# Out:
#      glucose  bloodpressure  diabetes
# 0         40             85         0
# 1         40             92         0
# 2         45             63         1
# 3         45             80         0
# 4         40             73         1
# ..       ...            ...       ...
# 990       45             87         0
# 991       40             83         0
# 992       40             83         0
# 993       40             60         1
# 994       45             82         0
#
# [995 rows x 3 columns]

# %%
fsdfcsdafcafsdafasdfasdfasdfagvfnosz ,.dskljai;ojdklsajdklasjdlkjfjlkasdjfmnlkascnl;asnvoefijfds;oooerbeftbfasdfadsfasdfasfwsadfewafdsafsdadsfsdfsd
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 13
#      10 for cluster in np.unique(train_clusters):
#      11     # Most common true label in each cluster
#      12     true_labels = y_train[train_clusters == cluster]
# ---> 13     cluster_label_map[cluster] = mode(true_labels)[0][0]
#      15 print("Cluster to class mapping:", cluster_label_map)
#      17 test_clusters = kmeans_model.predict(X_test)
#
# IndexError: invalid index to scalar variable.
