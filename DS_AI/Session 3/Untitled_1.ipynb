# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# Standardization
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)
labels_kmeans = kmeans.fit_predict(X_scaled)

sil_kmeans = silhouette_score(X_scaled, labels_kmeans)
print("K-Means Silhouette Score:", sil_kmeans)
# Out:
# K-Means Silhouette Score: 0.4798814508199817

# %%
from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(n_clusters=3, metric='euclidean', random_state=42)
labels_kmedoids = kmedoids.fit_predict(X_scaled)

sil_kmedoids = silhouette_score(X_scaled, labels_kmedoids)
print("K-Medoids Silhouette Score:", sil_kmedoids)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from sklearn_extra.cluster import KMedoids
#       3 kmedoids = KMedoids(n_clusters=3, metric='euclidean', random_state=42)
#       4 labels_kmedoids = kmedoids.fit_predict(X_scaled)
#
# File ~/Documents/206125030/DS_AI/venv/lib/python3.10/site-packages/sklearn_extra/__init__.py:1
# ----> 1 from . import kernel_approximation, kernel_methods  # noqa
#       3 from ._version import __version__
#       5 __all__ = ["__version__"]
#
# File ~/Documents/206125030/DS_AI/venv/lib/python3.10/site-packages/sklearn_extra/kernel_approximation/__init__.py:1
# ----> 1 from ._fastfood import Fastfood
#       4 __all__ = ["Fastfood"]
#
# File ~/Documents/206125030/DS_AI/venv/lib/python3.10/site-packages/sklearn_extra/kernel_approximation/_fastfood.py:11
#       8 from sklearn.base import TransformerMixin
#       9 from sklearn.utils import check_array, check_random_state
# ---> 11 from ..utils._cyfht import fht2 as cyfht
#      14 class Fastfood(BaseEstimator, TransformerMixin):
#      15     """Approximates feature map of an RBF kernel by Monte Carlo approximation
#      16     of its Fourier transform.
#      17
#    (...)
#      55
#      56     """
#
# File sklearn_extra/utils/_cyfht.pyx:1, in init sklearn_extra.utils._cyfht()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
